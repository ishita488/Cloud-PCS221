# %%
# ***Ishita Sikka - 902503030***
# ***Assignment 3***

# %%
# Part I: Randomized Sales Data Generation (NumPy)

# %%
# 1. Initialize Random Seed

import numpy as np

roll_number = 902503030
valid_seed = roll_number % (2**32)

rng = np.random.default_rng(valid_seed)

sales_data = rng.integers(1000, 5000, size=(12, 4))

print(sales_data)
# Out:
# [[2201 4954 2516 3658]
#  [4851 3092 4204 2047]
#  [2831 1658 1707 4709]
#  [2329 3610 4195 2130]
#  [1416 4064 2869 2253]
#  [3866 3475 2199 1667]
#  [2201 4037 4373 3721]
#  [3947 3567 3681 4480]
#  [2077 4986 1886 3075]
#  [3933 2076 3640 2096]
#  [4306 1460 4918 1618]
#  [4354 2032 4343 1686]]

# %%
# 2. Generate Sales Data (12 × 4)

# Generate random sales data between 1000 and 5000
sales_data = np.random.randint(1000, 5000, size=(12, 4))

sales_data
# Out:
# array([[2960, 4466, 1111, 2610],
#        [3816, 4488, 3986, 2114],
#        [2173, 2288, 2787, 4634],
#        [4710, 4672, 2364, 1033],
#        [4109, 1137, 2676, 4192],
#        [4357, 2281, 1184, 1134],
#        [1037, 2647, 2374, 1223],
#        [2988, 3911, 3947, 2376],
#        [3409, 2560, 1473, 3432],
#        [2415, 3694, 1875, 4340],
#        [2036, 2973, 2945, 4414],
#        [1270, 1803, 1228, 2270]])

# %%
import pandas as pd

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

# 3. Define columns
columns = ["Electronics", "Clothing", "Home & Kitchen", "Sports"]

# 4. Make sure sales_data is already defined
# Example:
# sales_data = [[100,200,150,80], [120,210,160,90], ...]

# 5. Convert to DataFrame
df = pd.DataFrame(sales_data, columns=columns, index=months)

# 6. Display
df
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         2960      4466            1111    2610
# Feb         3816      4488            3986    2114
# Mar         2173      2288            2787    4634
# Apr         4710      4672            2364    1033
# May         4109      1137            2676    4192
# Jun         4357      2281            1184    1134
# Jul         1037      2647            2374    1223
# Aug         2988      3911            3947    2376
# Sep         3409      2560            1473    3432
# Oct         2415      3694            1875    4340
# Nov         2036      2973            2945    4414
# Dec         1270      1803            1228    2270

# %%
# Part II: Data Manipulation and Analysis (Pandas)

# %%
# 1. First 5 Rows & Summary Statistics

df.head()
df.describe()
# Out:
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   2940.000000  3076.666667     2329.166667  2814.333333
# std    1190.447968  1153.899660     1001.001937  1349.306915
# min    1037.000000  1137.000000     1111.000000  1033.000000
# 25%    2138.750000  2286.250000     1411.750000  1891.250000
# 50%    2974.000000  2810.000000     2369.000000  2493.000000
# 75%    3889.250000  4049.750000     2826.500000  4229.000000
# max    4710.000000  4672.000000     3986.000000  4634.000000

# %%
# 2. Total Sales per Category & per Month

# Total per category
total_per_category = df.sum()
print("Total Sales per Category:\n", total_per_category)

# Total per month
total_per_month = df.sum(axis=1)
print("\nTotal Sales per Month:\n", total_per_month)
# Out:
# Total Sales per Category:
#  Electronics       35280
# Clothing          36920
# Home & Kitchen    27950
# Sports            33772
# dtype: int64
#
# Total Sales per Month:
#  Jan    11147
# Feb    14404
# Mar    11882
# Apr    12779
# May    12114
# Jun     8956
# Jul     7281
# Aug    13222
# Sep    10874
# Oct    12324
# Nov    12368
# Dec     6571
# dtype: int64

# %%
# 3. Average Sales Growth Between Consecutive Months

growth = df.pct_change()

avg_growth = growth.mean() * 100
print("Average Growth Rate (%):\n", avg_growth)
# Out:
# Average Growth Rate (%):
#  Electronics       12.676791
# Clothing           8.663605
# Home & Kitchen    27.372956
# Sports            34.682858
# dtype: float64

# %%
# 4. Add Total Sales & Growth Rate Columns

df["Total Sales"] = df.sum(axis=1)

df["Growth Rate"] = df["Total Sales"].pct_change() * 100

df
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         2960      4466            1111    2610        11147          NaN
# Feb         3816      4488            3986    2114        14404    29.218624
# Mar         2173      2288            2787    4634        11882   -17.509025
# Apr         4710      4672            2364    1033        12779     7.549234
# May         4109      1137            2676    4192        12114    -5.203850
# Jun         4357      2281            1184    1134         8956   -26.069011
# Jul         1037      2647            2374    1223         7281   -18.702546
# Aug         2988      3911            3947    2376        13222    81.595935
# Sep         3409      2560            1473    3432        10874   -17.758282
# Oct         2415      3694            1875    4340        12324    13.334559
# Nov         2036      2973            2945    4414        12368     0.357027
# Dec         1270      1803            1228    2270         6571   -46.870957

# %%
# 5. Apply Randomized Discount

if roll_number % 2 == 0:
    df["Electronics"] = df["Electronics"] * 0.9
    print("10% Discount Applied to Electronics")
else:
    df["Clothing"] = df["Clothing"] * 0.85
    print("15% Discount Applied to Clothing")

df.head()
# Out:
# 10% Discount Applied to Electronics
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan       2664.0      4466            1111    2610        11147          NaN
# Feb       3434.4      4488            3986    2114        14404    29.218624
# Mar       1955.7      2288            2787    4634        11882   -17.509025
# Apr       4239.0      4672            2364    1033        12779     7.549234
# May       3698.1      1137            2676    4192        12114    -5.203850

# %%
# Part III: Visualizations (Matplotlib & Seaborn)

# %%
import matplotlib.pyplot as plt

# 1. Monthly Sales Trends (Line Plot)

plt.figure(figsize=(10,6))

for column in columns:
    plt.plot(df.index, df[column], marker='o', label=column)

plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)
plt.show()

# %%
# 2. Box Plot – Sales Distribution
import seaborn as sns
plt.figure(figsize=(8,6))
sns.boxplot(data=df[columns])
plt.title("Sales Distribution by Category")
plt.show()

# %%
# Q.2 For the array: array = np.array([[1, -2, 3],[-4, 5, -6]])

# %%
# i) Element-wise Absolute Value

array = np.array([[1, -2, 3],[-4, 5, -6]])
np.abs(array)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# ii) Percentiles

# Flattened
np.percentile(array.flatten(), [25, 50, 75])

# Column-wise
np.percentile(array, [25, 50, 75], axis=0)

# Row-wise
np.percentile(array, [25, 50, 75], axis=1)
# Out:
# array([[-0.5, -5. ],
#        [ 1. , -4. ],
#        [ 2. ,  0.5]])

# %%
# iii) Mean, Median, Std

# Flattened
print("Mean:", np.mean(array))
print("Median:", np.median(array))
print("Std:", np.std(array))

# Column-wise
print("Column Mean:", np.mean(array, axis=0))
print("Column Median:", np.median(array, axis=0))
print("Column Std:", np.std(array, axis=0))

# Row-wise
print("Row Mean:", np.mean(array, axis=1))
print("Row Median:", np.median(array, axis=1))
print("Row Std:", np.std(array, axis=1))
# Out:
# Mean: -0.5
# Median: -0.5
# Std: 3.8622100754188224
# Column Mean: [-1.5  1.5 -1.5]
# Column Median: [-1.5  1.5 -1.5]
# Column Std: [2.5 3.5 4.5]
# Row Mean: [ 0.66666667 -1.66666667]
# Row Median: [ 1. -4.]
# Row Std: [2.05480467 4.78423336]

# %%
# Q.3 For the array: a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0]).

a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])

print("Floor:", np.floor(a))
print("Ceiling:", np.ceil(a))
print("Truncated:", np.trunc(a))
print("Rounded:", np.round(a))
# Out:
# Floor: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded: [-2. -2. -0.  0.  2.  2.  3.]

# %%
# Q.4 WAP to swap two elements in a list in Python Using a Temporary Variable.

lst = [10, 20, 30, 40]

pos1 = 1
pos2 = 3

temp = lst[pos1]
lst[pos1] = lst[pos2]
lst[pos2] = temp

print("Swapped List:", lst)
# Out:
# Swapped List: [10, 40, 30, 20]

# %%
# Q.5 Write a Python program to swap two elements in a set by converting it to a list first.

s = {1, 2, 3, 4}

# Convert to list
lst = list(s)

pos1 = 0
pos2 = 2

# Swap
lst[pos1], lst[pos2] = lst[pos2], lst[pos1]

# Convert back to set
s = set(lst)

print("Swapped Set:", s)
# Out:
# Swapped Set: {1, 2, 3, 4}
